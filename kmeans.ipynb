# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
np.random.seed(42)
data = {'annual':np.random.randint(30000,150000,100),
        "spedning score": np.random.randint(1,100,100)}
data= pd.DataFrame(data)
data
# Out:
#     annual  spedning score
# 0    45795              82
# 1    30860              53
# 2   133694              24
# 3   149879              26
# 4   140268              89
# ..     ...             ...
# 95  119789               1
# 96   85591              27
# 97  119812              62
# 98   53247              77
# 99   54300               3
#
# [100 rows x 2 columns]

# %%
plt.scatter(data['annual'],data['spedning score'])
plt.title("Income vs SS")
plt.xlabel("Income")
plt.ylabel("Spedning Score")
# Out:
# Text(0, 0.5, 'Spedning Score')

# %%
x= data.values
cluster = KMeans(n_clusters=3,random_state=9)
data['cluster']=cluster.fit_predict(x)
data['index']=np.arange(0,100,1)
data
# Out:
#     annual  spedning score  cluster  index
# 0    45795              82        0      0
# 1    30860              53        0      1
# 2   133694              24        2      2
# 3   149879              26        2      3
# 4   140268              89        2      4
# ..     ...             ...      ...    ...
# 95  119789               1        2     95
# 96   85591              27        1     96
# 97  119812              62        2     97
# 98   53247              77        0     98
# 99   54300               3        0     99
#
# [100 rows x 4 columns]

# %%
plt.scatter(data['annual'],data['spedning score'],c=data['cluster'],cmap='rainbow')
plt.title("Income vs SS")
plt.xlabel("Income")
plt.ylabel("Spedning Score")
# Out:
# Text(0, 0.5, 'Spedning Score')
